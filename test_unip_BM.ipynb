# %%
# %load_ext autoreload
# %autoreload 2
from combunipotent import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
dpart, rtype = (23,23,23,17,17,9,9,9,9,9,5,5), 'D'
res = test_dpart2drcLS(dpart,rtype,test=False)
# Out:
# Group type D, dual partition:  (0,)
# (0,)
# The dBV(dO): D, []
# #DRCS:  1,      #ALS    1
# #GDRCS: 1,      #GLS    1
# Group type C, dual partition:  (5, 0)
# The dBV(dO): C, [4]
# #DRCS:  1,      #ALS    1
# #GDRCS: 1,      #GLS    1
# Group type D, dual partition:  (5, 5, 0)
# The dBV(dO): D, [6, 4]
# #DRCS:  4,      #ALS    8
# #GDRCS: 4,      #GLS    8
# Group type C, dual partition:  (9, 5, 5, 0)
# The dBV(dO): C, [8, 6, 4]
# #DRCS:  8,      #ALS    8
# #GDRCS: 8,      #GLS    8
# Group type D, dual partition:  (9, 9, 5, 5, 0)
# The dBV(dO): D, [10, 8, 6, 4]
# #DRCS:  32,     #ALS    64
# #GDRCS: 32,     #GLS    64
# Group type C, dual partition:  (9, 9, 9, 5, 5, 0)
# The dBV(dO): C, [9, 9, 8, 6, 4]
# #DRCS:  24,     #ALS    24
# #GDRCS: 24,     #GLS    24
# Group type D, dual partition:  (9, 9, 9, 9, 5, 5, 0)
# The dBV(dO): D, [10, 9, 9, 8, 6, 4]
# #DRCS:  64,     #ALS    128
# #GDRCS: 64,     #GLS    128
# Group type C, dual partition:  (9, 9, 9, 9, 9, 5, 5, 0)
# The dBV(dO): C, [9, 9, 9, 9, 8, 6, 4]
# #DRCS:  40,     #ALS    40
# #GDRCS: 40,     #GLS    40
# Group type D, dual partition:  (17, 9, 9, 9, 9, 9, 5, 5, 0)
# The dBV(dO): D, [18, 9, 9, 9, 9, 8, 6, 4]
# #DRCS:  736,    #ALS    1440
# #GDRCS: 736,    #GLS    1440
# Group type C, dual partition:  (17, 17, 9, 9, 9, 9, 9, 5, 5, 0)
# The dBV(dO): C, [17, 17, 9, 9, 9, 9, 8, 6, 4]
# #DRCS:  696,    #ALS    680
# #GDRCS: 696,    #GLS    680
# Group type D, dual partition:  (23, 17, 17, 9, 9, 9, 9, 9, 5, 5, 0)
# The dBV(dO): D, [24, 17, 17, 9, 9, 9, 9, 8, 6, 4]
# #DRCS:  10400,  #ALS    20320
# #GDRCS: 10400,  #GLS    20320
# Group type C, dual partition:  (23, 23, 17, 17, 9, 9, 9, 9, 9, 5, 5, 0)
# The dBV(dO): C, [23, 23, 17, 17, 9, 9, 9, 9, 8, 6, 4]
# #DRCS:  9704,   #ALS    9480
# #GDRCS: 9704,   #GLS    9480
# Group type D, dual partition:  (23, 23, 23, 17, 17, 9, 9, 9, 9, 9, 5, 5, 0)
# The dBV(dO): D, [24, 23, 23, 17, 17, 9, 9, 9, 9, 8, 6, 4]
# #DRCS:  28416,  #ALS    55520
# #GDRCS: 28416,  #GLS    55520

# %%
part, rtype = (2,2,2,2,2,2,1,1), 'M'
#part, rtype = (2,2,2,2,2,2,2,2,2,2), 'M'
part, rtype = (2,2), 'C'
part2drc(part,rtype=rtype,print_Wrepn=True,printdig=False)
gg = gen_lift_graph(part,rtype,format='pdf')
gg.render()
display(gg)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">Type C partition: <span style="font-weight: bold">(</span><span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span><span style="font-weight: bold">)</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">List of relevent Weyl group representations
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="font-weight: bold">[([</span><span style="color: #000080; font-weight: bold">1</span><span style="font-weight: bold">]</span>, <span style="font-weight: bold">[</span><span style="color: #000080; font-weight: bold">1</span><span style="font-weight: bold">])</span>, <span style="font-weight: bold">([</span><span style="color: #000080; font-weight: bold">2</span><span style="font-weight: bold">]</span>, <span style="font-weight: bold">[])]</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="font-weight: bold">[</span><span style="color: #000080; font-weight: bold">4</span>, <span style="color: #000080; font-weight: bold">4</span><span style="font-weight: bold">]</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">Number of drc diagrams: <span style="color: #000080; font-weight: bold">8</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="font-weight: bold">[</span><span style="color: #000080; font-weight: bold">4</span><span style="font-weight: bold">]</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">Partition type D  <span style="font-weight: bold">(</span><span style="color: #000080; font-weight: bold">2</span>,<span style="font-weight: bold">)</span>:
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#DRCS:  <span style="color: #000080; font-weight: bold">4</span>,      #ALS    <span style="color: #000080; font-weight: bold">8</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#GDRCS: <span style="color: #000080; font-weight: bold">4</span>,      #GLS    <span style="color: #000080; font-weight: bold">8</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="font-weight: bold">[</span><span style="color: #000080; font-weight: bold">4</span>, <span style="color: #000080; font-weight: bold">4</span><span style="font-weight: bold">]</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">Partition type C  <span style="font-weight: bold">(</span><span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span><span style="font-weight: bold">)</span>:
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#DRCS:  <span style="color: #000080; font-weight: bold">8</span>,      #ALS    <span style="color: #000080; font-weight: bold">8</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#GDRCS: <span style="color: #000080; font-weight: bold">8</span>,      #GLS    <span style="color: #000080; font-weight: bold">8</span>
# </pre>

# %%
part, rtype = (3,3,1,1), 'M'
part2drc(part,rtype=rtype,print_Wrepn=True,printdig=True);

# %%
part = [7,7,6,6,5,5,4,4,3,3,2,2,1,1]
part = [7,7,5,5,3,3,1,1]
part = [13,13,2,2,1,1]
#part = [3,3,2,2,1,1]
#part = [2,2,1,1]
part = [8,8,8,8,8,8,5,5,2,2,2,2,2,2,2,2]
part = [4,4,4,4,4,4,2,2,2,2,2,2,2,2]
rtype = 'M'
test_purelyeven(part,rtype=rtype);
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="font-weight: bold">[</span><span style="color: #000080; font-weight: bold">3</span><span style="font-weight: bold">]</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">Partition type B  <span style="font-weight: bold">(</span><span style="color: #000080; font-weight: bold">3</span>,<span style="font-weight: bold">)</span>:
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#DRCS:  <span style="color: #000080; font-weight: bold">3</span>,      #ALS    <span style="color: #000080; font-weight: bold">12</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#GDRCS: <span style="color: #000080; font-weight: bold">6</span>,      #GLS    <span style="color: #000080; font-weight: bold">12</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="font-weight: bold">[</span><span style="color: #000080; font-weight: bold">5</span><span style="font-weight: bold">]</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">Partition type M  <span style="font-weight: bold">[</span><span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span><span style="font-weight: bold">]</span>:
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#DRCS:  <span style="color: #000080; font-weight: bold">5</span>,      #ALS    <span style="color: #000080; font-weight: bold">5</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#GDRCS: <span style="color: #000080; font-weight: bold">5</span>,      #GLS    <span style="color: #000080; font-weight: bold">5</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="font-weight: bold">[</span><span style="color: #000080; font-weight: bold">7</span><span style="font-weight: bold">]</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">Partition type B  <span style="font-weight: bold">(</span><span style="color: #000080; font-weight: bold">3</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span><span style="font-weight: bold">)</span>:
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#DRCS:  <span style="color: #000080; font-weight: bold">7</span>,      #ALS    <span style="color: #000080; font-weight: bold">28</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#GDRCS: <span style="color: #000080; font-weight: bold">14</span>,     #GLS    <span style="color: #000080; font-weight: bold">28</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="font-weight: bold">[</span><span style="color: #000080; font-weight: bold">9</span><span style="font-weight: bold">]</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">Partition type M  <span style="font-weight: bold">[</span><span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span><span style="font-weight: bold">]</span>:
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#DRCS:  <span style="color: #000080; font-weight: bold">9</span>,      #ALS    <span style="color: #000080; font-weight: bold">9</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#GDRCS: <span style="color: #000080; font-weight: bold">9</span>,      #GLS    <span style="color: #000080; font-weight: bold">9</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="font-weight: bold">[</span><span style="color: #000080; font-weight: bold">11</span><span style="font-weight: bold">]</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">Partition type B  <span style="font-weight: bold">(</span><span style="color: #000080; font-weight: bold">3</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span><span style="font-weight: bold">)</span>:
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#DRCS:  <span style="color: #000080; font-weight: bold">11</span>,     #ALS    <span style="color: #000080; font-weight: bold">40</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#GDRCS: <span style="color: #000080; font-weight: bold">22</span>,     #GLS    <span style="color: #000080; font-weight: bold">40</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="font-weight: bold">[</span><span style="color: #000080; font-weight: bold">13</span><span style="font-weight: bold">]</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">Partition type M  <span style="font-weight: bold">[</span><span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span><span style="font-weight: bold">]</span>:
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#DRCS:  <span style="color: #000080; font-weight: bold">13</span>,     #ALS    <span style="color: #000080; font-weight: bold">10</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#GDRCS: <span style="color: #000080; font-weight: bold">13</span>,     #GLS    <span style="color: #000080; font-weight: bold">10</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="font-weight: bold">[</span><span style="color: #000080; font-weight: bold">15</span><span style="font-weight: bold">]</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">Partition type B  <span style="font-weight: bold">(</span><span style="color: #000080; font-weight: bold">3</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span><span style="font-weight: bold">)</span>:
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#DRCS:  <span style="color: #000080; font-weight: bold">15</span>,     #ALS    <span style="color: #000080; font-weight: bold">40</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#GDRCS: <span style="color: #000080; font-weight: bold">30</span>,     #GLS    <span style="color: #000080; font-weight: bold">40</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="font-weight: bold">[</span><span style="color: #000080; font-weight: bold">17</span><span style="font-weight: bold">]</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">Partition type M  <span style="font-weight: bold">[</span><span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span><span style="font-weight: bold">]</span>:
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#DRCS:  <span style="color: #000080; font-weight: bold">17</span>,     #ALS    <span style="color: #000080; font-weight: bold">10</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#GDRCS: <span style="color: #000080; font-weight: bold">17</span>,     #GLS    <span style="color: #000080; font-weight: bold">10</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="font-weight: bold">[</span><span style="color: #000080; font-weight: bold">53</span><span style="font-weight: bold">]</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">Partition type B  <span style="font-weight: bold">(</span><span style="color: #000080; font-weight: bold">5</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span><span style="font-weight: bold">)</span>:
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#DRCS:  <span style="color: #000080; font-weight: bold">53</span>,     #ALS    <span style="color: #000080; font-weight: bold">120</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#GDRCS: <span style="color: #000080; font-weight: bold">106</span>,    #GLS    <span style="color: #000080; font-weight: bold">120</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="font-weight: bold">[</span><span style="color: #000080; font-weight: bold">89</span><span style="font-weight: bold">]</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">Partition type M  <span style="font-weight: bold">[</span><span style="color: #000080; font-weight: bold">4</span>, <span style="color: #000080; font-weight: bold">4</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span><span style="font-weight: bold">]</span>:
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#DRCS:  <span style="color: #000080; font-weight: bold">89</span>,     #ALS    <span style="color: #000080; font-weight: bold">50</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#GDRCS: <span style="color: #000080; font-weight: bold">89</span>,     #GLS    <span style="color: #000080; font-weight: bold">50</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="font-weight: bold">[</span><span style="color: #000080; font-weight: bold">125</span><span style="font-weight: bold">]</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">Partition type B  <span style="font-weight: bold">(</span><span style="color: #000080; font-weight: bold">5</span>, <span style="color: #000080; font-weight: bold">4</span>, <span style="color: #000080; font-weight: bold">4</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span><span style="font-weight: bold">)</span>:
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#DRCS:  <span style="color: #000080; font-weight: bold">125</span>,    #ALS    <span style="color: #000080; font-weight: bold">280</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#GDRCS: <span style="color: #000080; font-weight: bold">250</span>,    #GLS    <span style="color: #000080; font-weight: bold">280</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="font-weight: bold">[</span><span style="color: #000080; font-weight: bold">161</span><span style="font-weight: bold">]</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">Partition type M  <span style="font-weight: bold">[</span><span style="color: #000080; font-weight: bold">4</span>, <span style="color: #000080; font-weight: bold">4</span>, <span style="color: #000080; font-weight: bold">4</span>, <span style="color: #000080; font-weight: bold">4</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span><span style="font-weight: bold">]</span>:
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#DRCS:  <span style="color: #000080; font-weight: bold">161</span>,    #ALS    <span style="color: #000080; font-weight: bold">90</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#GDRCS: <span style="color: #000080; font-weight: bold">161</span>,    #GLS    <span style="color: #000080; font-weight: bold">90</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="font-weight: bold">[</span><span style="color: #000080; font-weight: bold">197</span><span style="font-weight: bold">]</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">Partition type B  <span style="font-weight: bold">(</span><span style="color: #000080; font-weight: bold">5</span>, <span style="color: #000080; font-weight: bold">4</span>, <span style="color: #000080; font-weight: bold">4</span>, <span style="color: #000080; font-weight: bold">4</span>, <span style="color: #000080; font-weight: bold">4</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span><span style="font-weight: bold">)</span>:
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#DRCS:  <span style="color: #000080; font-weight: bold">197</span>,    #ALS    <span style="color: #000080; font-weight: bold">408</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#GDRCS: <span style="color: #000080; font-weight: bold">394</span>,    #GLS    <span style="color: #000080; font-weight: bold">408</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="font-weight: bold">[</span><span style="color: #000080; font-weight: bold">233</span><span style="font-weight: bold">]</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">Partition type M  <span style="font-weight: bold">[</span><span style="color: #000080; font-weight: bold">4</span>, <span style="color: #000080; font-weight: bold">4</span>, <span style="color: #000080; font-weight: bold">4</span>, <span style="color: #000080; font-weight: bold">4</span>, <span style="color: #000080; font-weight: bold">4</span>, <span style="color: #000080; font-weight: bold">4</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span><span style="font-weight: bold">]</span>:
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#DRCS:  <span style="color: #000080; font-weight: bold">233</span>,    #ALS    <span style="color: #000080; font-weight: bold">102</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#GDRCS: <span style="color: #000080; font-weight: bold">233</span>,    #GLS    <span style="color: #000080; font-weight: bold">102</span>
# </pre>

# %%
part = [7,5,5,3,3]
#part = [5,4,4]
part = [15,13,13,8,8,8,8,3,3,2,2,2,2,1,1]

b = part2drc(part,'B',print_Wrepn=False,printdig=False)
c = print_list_LS(part,'B')
#compare_drc(a,b)
# Out:
# Type B partition: [15, 13, 13, 8, 8, 8, 8, 3, 3, 2, 2, 2, 2, 1, 1]
# [10560, 10560, 10560, 10560, 10560, 10560, 10560, 10560]
# Number of drc diagrams: 84480
# Type B  partition: [15, 13, 13, 8, 8, 8, 8, 3, 3, 2, 2, 2, 2, 1, 1]
# Number of LS: 279040

# %%
part = (8,8,7,7,5,5,1,1)
rtype = 'M'
test_purelyeven(part,rtype=rtype);

# %%
part = [2,2,2,2,2,2,2,2,1,1]
rtype = 'M'
test_purelyeven(part,rtype=rtype);

# %%
## Example of strange annihlation of LS
test_LSDRC([8,3,3,1,1],'D',report=False,reportann=True)

# %%
test_LSDRC([4,3,3,2,2,1,1],'D',report=False, reportann=True)

# %%
partM = [3,3]
DRCLS1 = lift_drcs(dict(),rtype='B',ltype=partM[-1])
DRCLS2 = lift_drcs(DRCLS1, rtype='M', ltype='l')
print_list_LS(partM,'M')
print_DRCLS(DRCLS1, 'B')
print('DRCLS',len(DRCLS2))
print_DRCLS(DRCLS2,'M')

# %%
test_LSDRC([9,6,6,3,3,2,2,1,1],'B',report=False)

# %%
test_LSDRC([7,6,6,5,5,4,4,3,3,2,2,1,1],'B',report=False)

# %%
test_LSDRC([6,5,5,4,4,3,3,2,2,1,1],'D',report=False)

# %%
test_LSDRC([6,6,5,5,4,4,3,3,2,2,1,1],'M', report=False)

# %%
#part0, parta, rtype=(3,3,2,2,1,1), (3,3), 'C'
part0, parta, rtype=(1,1), (1,1), 'C'
part = parta*2+part0
part2drc(part0,rtype, printdig=True)
part2LS(part0,rtype, printdig=True)
#part, rtype=[1,1,1,1], 'C'
part2drc(part,rtype,printdig = True)
part2LS(part,rtype, printdig=True)

# %%
#part,rtype=(4,3,3,1,1), 'D'
part,rtype=(1,1,)*5,'C'
test_LSDRC(part,rtype,report=True,reportann=False)

# %%
#part,rtype=(4,3,3,1,1), 'D'
part,rtype=(5,5)*4+(3,3,)*5+(2,2),'C'
#part,rtype=(6,6,2,2,1,1),'C'
#part,rtype=(1,1,)*5,'C'
part,rtype=(7,7)*5+(2,2)+(1,1)*4,'C'
test_purelyeven(part,rtype,report=False,reportann=False)

# %%
#part,rtype=(4,3,3,1,1), 'D'
#part,rtype=(5,5)*4+(4,4)+(3,3,)*4+(2,2)+(1,1,)*4,'C'
part,rtype=(4,4)*5+(3,3)+(2,2,)*5,'M'
#part,rtype=(2,2,)*4,'M'
test_purelyeven(part,rtype,report=False,reportann=False)
0

# %%
#part,rtype=(4,3,3,1,1), 'D' 
#part,rtype=(5,5)*4+(4,4)+(3,3,)*4+(2,2)+(1,1,)*4,'C'
part,rtype=(3,3,)*5+(2,2),'C'
test_purelyeven(part,rtype,report=False,reportann=False,reportpack=False)

# %%
#part,rtype=(4,3,3,1,1), 'D'
#part,rtype=(5,5)*4+(4,4)+(3,3,)*4+(2,2)+(1,1,)*4,'C'
#part,rtype=(4,4)*5+(3,3)+(2,2,)*5,'M'
part,rtype=(4,2,2,),'D'
test_purelyeven(part,rtype,report=True,reportann=False)

# %%
part,rtype=(2,1,1,),'D'
test_purelyeven(part,rtype,report=False,reportann=False);

# %%
part,rtype=(3,1,1,),'D'
test_purelyeven(part,rtype,report=True,reportann=False)
0

# %%
''.join(range(0))

# %%
a = 'abc'
('',*a)

# %%
springer_part2repn((3,3,3),'C')

# %%
springer_repn2part(((3,2),(2,1)),'D')

# %%
dO,rtype = (5,5,1),'C'
RR = dualpart2Wrepn(dO,rtype)
print(RR)

# %%
dO, rtype = (6,6,6,6,4,4,4,4),'D'
stau = part2srepn(dO,rtype)
print(stau)
RES = part2dbcell(dO,rtype)
print(RES)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="font-weight: bold">((</span><span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">3</span>, <span style="color: #000080; font-weight: bold">3</span><span style="font-weight: bold">)</span>, <span style="font-weight: bold">(</span><span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">3</span>, <span style="color: #000080; font-weight: bold">3</span><span style="font-weight: bold">))</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="font-weight: bold">[((</span><span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">3</span>, <span style="color: #000080; font-weight: bold">3</span><span style="font-weight: bold">)</span>, <span style="font-weight: bold">(</span><span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">3</span>, <span style="color: #000080; font-weight: bold">3</span><span style="font-weight: bold">))]</span>
# </pre>

# %%
dO, rtype = (7,7,4,4,4,4,1,1),'C'
print(dualBVW(dO,'C',partrc='c'))
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="font-weight: bold">[</span><span style="color: #000080; font-weight: bold">8</span>, <span style="color: #000080; font-weight: bold">6</span>, <span style="color: #000080; font-weight: bold">4</span>, <span style="color: #000080; font-weight: bold">4</span>, <span style="color: #000080; font-weight: bold">4</span>, <span style="color: #000080; font-weight: bold">4</span>, <span style="color: #000080; font-weight: bold">2</span><span style="font-weight: bold">]</span>
# </pre>

# %%
dO, rtype = (1,1),'D'
stau = part2srepn(dO,rtype)
print(stau)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="font-weight: bold">(()</span>, <span style="font-weight: bold">(</span><span style="color: #000080; font-weight: bold">1</span>,<span style="font-weight: bold">))</span>
# </pre>

# %%
part, rtype = (10,8,6,4,2), 'C'
#part, rtype = (2,2,2,2,2,2,2,2,2,2), 'M'

part2drc(part,rtype=rtype,print_Wrepn=True,printdig=False)
gg = gen_lift_graph(part,rtype,format='pdf')
gg.render()
display(gg)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">Type C partition: <span style="font-weight: bold">(</span><span style="color: #000080; font-weight: bold">10</span>, <span style="color: #000080; font-weight: bold">8</span>, <span style="color: #000080; font-weight: bold">6</span>, <span style="color: #000080; font-weight: bold">4</span>, <span style="color: #000080; font-weight: bold">2</span><span style="font-weight: bold">)</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">List of relevent Weyl group representations
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="font-weight: bold">[([</span><span style="color: #000080; font-weight: bold">4</span>, <span style="color: #000080; font-weight: bold">2</span><span style="font-weight: bold">]</span>, <span style="font-weight: bold">[</span><span style="color: #000080; font-weight: bold">5</span>, <span style="color: #000080; font-weight: bold">3</span>, <span style="color: #000080; font-weight: bold">1</span><span style="font-weight: bold">])</span>, <span style="font-weight: bold">([</span><span style="color: #000080; font-weight: bold">4</span>, <span style="color: #000080; font-weight: bold">4</span><span style="font-weight: bold">]</span>, <span style="font-weight: bold">[</span><span style="color: #000080; font-weight: bold">5</span>, <span style="color: #000080; font-weight: bold">1</span>, <span style="color: #000080; font-weight: bold">1</span><span style="font-weight: bold">])</span>, <span style="font-weight: bold">([</span><span style="color: #000080; font-weight: bold">6</span>, <span style="color: #000080; font-weight: bold">2</span><span style="font-weight: bold">]</span>, <span style="font-weight: bold">[</span><span style="color: #000080; font-weight: bold">3</span>, <span style="color: #000080; font-weight: bold">3</span>, <span style="color: #000080; font-weight: bold">1</span><span style="font-weight: bold">])</span>, <span style="font-weight: bold">([</span><span style="color: #000080; font-weight: bold">6</span>, <span style="color: #000080; font-weight: bold">4</span><span style="font-weight: bold">]</span>, <span style="font-weight: bold">[</span><span style="color: #000080; font-weight: bold">3</span>, <span style="color: #000080; font-weight: bold">1</span>, <span style="color: #000080; font-weight: bold">1</span><span style="font-weight: bold">])]</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="font-weight: bold">[</span><span style="color: #000080; font-weight: bold">16</span>, <span style="color: #000080; font-weight: bold">16</span>, <span style="color: #000080; font-weight: bold">16</span>, <span style="color: #000080; font-weight: bold">16</span><span style="font-weight: bold">]</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">Number of drc diagrams: <span style="color: #000080; font-weight: bold">64</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="font-weight: bold">[</span><span style="color: #000080; font-weight: bold">1</span><span style="font-weight: bold">]</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">Partition type C  <span style="font-weight: bold">(</span><span style="color: #000080; font-weight: bold">2</span>,<span style="font-weight: bold">)</span>:
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#DRCS:  <span style="color: #000080; font-weight: bold">1</span>,      #ALS    <span style="color: #000080; font-weight: bold">1</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#GDRCS: <span style="color: #000080; font-weight: bold">0</span>,      #GLS    <span style="color: #000080; font-weight: bold">0</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">Number of all DRCS: <span style="color: #000080; font-weight: bold">1</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">Number of lifted DRCS: <span style="color: #000080; font-weight: bold">0</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">|s
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="color: #000080; font-weight: bold">1</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">Missing <span style="color: #000080; font-weight: bold">1</span> LS:
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">+
# -
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">~~~~~~~~~~~~~~~
# </pre>

# %%
part, rtype = (6,6,5,5,2,2), 'C'
#part, rtype = (2,2,2,2,2,2,2,2,2,2), 'M'

part2drc(part,rtype=rtype,print_Wrepn=True,printdig=False)
gg = gen_lift_graph(part,rtype,format='pdf')
gg.render()
display(gg)
# Out:
# Type C partition: (6, 6, 5, 5, 2, 2)
# List of relevent Weyl group representations
# [([3, 3, 1], [3, 2, 1]), ([3, 3, 2], [3, 2]), ([4, 3, 1], [2, 2, 1]), ([4, 3, 2], [2, 2])]
# [80, 80, 80, 80]
# Number of drc diagrams: 320
# [4]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">Partition type D  <span style="font-weight: bold">(</span><span style="color: #000080; font-weight: bold">2</span>,<span style="font-weight: bold">)</span>:
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#DRCS:  <span style="color: #000080; font-weight: bold">4</span>,      #ALS    <span style="color: #000080; font-weight: bold">8</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#GDRCS: <span style="color: #000080; font-weight: bold">4</span>,      #GLS    <span style="color: #000080; font-weight: bold">8</span>
# </pre>
# [4, 4]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">Partition type C  <span style="font-weight: bold">(</span><span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span><span style="font-weight: bold">)</span>:
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#DRCS:  <span style="color: #000080; font-weight: bold">8</span>,      #ALS    <span style="color: #000080; font-weight: bold">8</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#GDRCS: <span style="color: #000080; font-weight: bold">8</span>,      #GLS    <span style="color: #000080; font-weight: bold">8</span>
# </pre>
# [32, 32]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">Partition type D  <span style="font-weight: bold">(</span><span style="color: #000080; font-weight: bold">6</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span><span style="font-weight: bold">)</span>:
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#DRCS:  <span style="color: #000080; font-weight: bold">64</span>,     #ALS    <span style="color: #000080; font-weight: bold">128</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#GDRCS: <span style="color: #000080; font-weight: bold">64</span>,     #GLS    <span style="color: #000080; font-weight: bold">128</span>
# </pre>
# [28, 28]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">Partition type C  <span style="font-weight: bold">(</span><span style="color: #000080; font-weight: bold">5</span>, <span style="color: #000080; font-weight: bold">5</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span><span style="font-weight: bold">)</span>:
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#DRCS:  <span style="color: #000080; font-weight: bold">56</span>,     #ALS    <span style="color: #000080; font-weight: bold">56</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#GDRCS: <span style="color: #000080; font-weight: bold">56</span>,     #GLS    <span style="color: #000080; font-weight: bold">56</span>
# </pre>
# [80, 80]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">Partition type D  <span style="font-weight: bold">(</span><span style="color: #000080; font-weight: bold">6</span>, <span style="color: #000080; font-weight: bold">5</span>, <span style="color: #000080; font-weight: bold">5</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span><span style="font-weight: bold">)</span>:
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#DRCS:  <span style="color: #000080; font-weight: bold">160</span>,    #ALS    <span style="color: #000080; font-weight: bold">320</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#GDRCS: <span style="color: #000080; font-weight: bold">160</span>,    #GLS    <span style="color: #000080; font-weight: bold">320</span>
# </pre>
# [80, 80, 80, 80]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">Partition type C  <span style="font-weight: bold">(</span><span style="color: #000080; font-weight: bold">6</span>, <span style="color: #000080; font-weight: bold">6</span>, <span style="color: #000080; font-weight: bold">5</span>, <span style="color: #000080; font-weight: bold">5</span>, <span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">2</span><span style="font-weight: bold">)</span>:
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#DRCS:  <span style="color: #000080; font-weight: bold">320</span>,    #ALS    <span style="color: #000080; font-weight: bold">320</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#GDRCS: <span style="color: #000080; font-weight: bold">320</span>,    #GLS    <span style="color: #000080; font-weight: bold">320</span>
# </pre>

# %%
part, rtype = (2,2,2,2,2,2,1,1), 'M'
#part, rtype = (2,2,2,2,2,2,2,2,2,2), 'M'
part, rtype = (1,1,1,1), 'C'
part2drc(part,rtype=rtype,print_Wrepn=True,printdig=False)
gg = gen_lift_graph(part,rtype,format='pdf')
gg.render()
display(gg)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">Type C partition: <span style="font-weight: bold">(</span><span style="color: #000080; font-weight: bold">1</span>, <span style="color: #000080; font-weight: bold">1</span>, <span style="color: #000080; font-weight: bold">1</span>, <span style="color: #000080; font-weight: bold">1</span><span style="font-weight: bold">)</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">List of relevent Weyl group representations
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="font-weight: bold">[([</span><span style="color: #000080; font-weight: bold">1</span>, <span style="color: #000080; font-weight: bold">1</span><span style="font-weight: bold">]</span>, <span style="font-weight: bold">[])]</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="font-weight: bold">[</span><span style="color: #000080; font-weight: bold">5</span><span style="font-weight: bold">]</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">Number of drc diagrams: <span style="color: #000080; font-weight: bold">5</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="font-weight: bold">[</span><span style="color: #000080; font-weight: bold">4</span><span style="font-weight: bold">]</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">Partition type D  <span style="font-weight: bold">(</span><span style="color: #000080; font-weight: bold">2</span>,<span style="font-weight: bold">)</span>:
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#DRCS:  <span style="color: #000080; font-weight: bold">4</span>,      #ALS    <span style="color: #000080; font-weight: bold">8</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#GDRCS: <span style="color: #000080; font-weight: bold">4</span>,      #GLS    <span style="color: #000080; font-weight: bold">8</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="font-weight: bold">[</span><span style="color: #000080; font-weight: bold">3</span><span style="font-weight: bold">]</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">Partition type C  <span style="font-weight: bold">(</span><span style="color: #000080; font-weight: bold">1</span>, <span style="color: #000080; font-weight: bold">1</span><span style="font-weight: bold">)</span>:
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#DRCS:  <span style="color: #000080; font-weight: bold">3</span>,      #ALS    <span style="color: #000080; font-weight: bold">3</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#GDRCS: <span style="color: #000080; font-weight: bold">3</span>,      #GLS    <span style="color: #000080; font-weight: bold">3</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="font-weight: bold">[</span><span style="color: #000080; font-weight: bold">8</span><span style="font-weight: bold">]</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">Partition type D  <span style="font-weight: bold">(</span><span style="color: #000080; font-weight: bold">2</span>, <span style="color: #000080; font-weight: bold">1</span>, <span style="color: #000080; font-weight: bold">1</span><span style="font-weight: bold">)</span>:
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#DRCS:  <span style="color: #000080; font-weight: bold">8</span>,      #ALS    <span style="color: #000080; font-weight: bold">16</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#GDRCS: <span style="color: #000080; font-weight: bold">8</span>,      #GLS    <span style="color: #000080; font-weight: bold">16</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="font-weight: bold">[</span><span style="color: #000080; font-weight: bold">5</span><span style="font-weight: bold">]</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">Partition type C  <span style="font-weight: bold">(</span><span style="color: #000080; font-weight: bold">1</span>, <span style="color: #000080; font-weight: bold">1</span>, <span style="color: #000080; font-weight: bold">1</span>, <span style="color: #000080; font-weight: bold">1</span><span style="font-weight: bold">)</span>:
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#DRCS:  <span style="color: #000080; font-weight: bold">5</span>,      #ALS    <span style="color: #000080; font-weight: bold">5</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">#GDRCS: <span style="color: #000080; font-weight: bold">5</span>,      #GLS    <span style="color: #000080; font-weight: bold">5</span>
# </pre>

# %%
a = ''
a[-1:]
# Out:
# ''
