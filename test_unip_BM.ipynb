# %%
# %load_ext autoreload
# %autoreload 2
from combunipotent import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
dpart, rtype = (7,7,7,7,7,5,3,3,1,1), 'D'
res = test_dpart2drcLS(dpart,rtype,test=False)
# Out:
# Group type D, dual partition:  (0,)
# (0,)
# The dBV(dO): D, []
# #PBP:   1, #PBP*2:      2,      #ALS    1
# #GPBP:  1, #GPBP*2:     2,      #GLS    1
# Group type C, dual partition:  (1, 0)
# The dBV(dO): C, []
# #DRCS:  1,      #ALS    1
# #GDRCS: 1,      #GLS    1
# Group type D, dual partition:  (1, 1, 0)
# The dBV(dO): D, [2]
# #PBP:   4, #PBP*2:      8,      #ALS    8
# #GPBP:  4, #GPBP*2:     8,      #GLS    8
# Group type C, dual partition:  (3, 1, 1, 0)
# The dBV(dO): C, [2, 2]
# #DRCS:  8,      #ALS    8
# #GDRCS: 8,      #GLS    8
# Group type D, dual partition:  (3, 3, 1, 1, 0)
# The dBV(dO): D, [4, 2, 2]
# #PBP:   32, #PBP*2:     64,     #ALS    64
# #GPBP:  32, #GPBP*2:    64,     #GLS    64
# Group type C, dual partition:  (5, 3, 3, 1, 1, 0)
# The dBV(dO): C, [4, 4, 2, 2]
# #DRCS:  64,     #ALS    64
# #GDRCS: 64,     #GLS    64
# Group type D, dual partition:  (7, 5, 3, 3, 1, 1, 0)
# The dBV(dO): D, [8, 4, 4, 2, 2]
# #PBP:   512, #PBP*2:    1024,   #ALS    1024
# #GPBP:  512, #GPBP*2:   1024,   #GLS    1024
# Group type C, dual partition:  (7, 7, 5, 3, 3, 1, 1, 0)
# The dBV(dO): C, [7, 7, 4, 4, 2, 2]
# #DRCS:  448,    #ALS    448
# #GDRCS: 448,    #GLS    448
# Group type D, dual partition:  (7, 7, 7, 5, 3, 3, 1, 1, 0)
# The dBV(dO): D, [8, 7, 7, 4, 4, 2, 2]
# #PBP:   1280, #PBP*2:   2560,   #ALS    2560
# #GPBP:  1280, #GPBP*2:  2560,   #GLS    2560
# Group type C, dual partition:  (7, 7, 7, 7, 5, 3, 3, 1, 1, 0)
# The dBV(dO): C, [7, 7, 7, 7, 4, 4, 2, 2]
# #DRCS:  832,    #ALS    832
# #GDRCS: 832,    #GLS    832
# Group type D, dual partition:  (7, 7, 7, 7, 7, 5, 3, 3, 1, 1, 0)
# The dBV(dO): D, [8, 7, 7, 7, 7, 4, 4, 2, 2]
# #PBP:   2048, #PBP*2:   4096,   #ALS    3840
# #GPBP:  2048, #GPBP*2:  4096,   #GLS    3840

# %%
dpart, rtype = (4,4,4,4,2), 'B'
res = test_dpart2drcLS(dpart,rtype,test=False)
# Out:
# Group type M, dual partition:  (0,)
# The dBV(dO): M, []
# #DRCS:  1,      #ALS    1
# #GDRCS: 1,      #GLS    1
# Group type B, dual partition:  (2, 0)
# The dBV(dO): B, [3]
# #PBPext:        6, #PBPext*2:   12,     #ALS    12
# #GPBPext:       6, #GPBPext*2:  12,     #GLS    12
# Group type M, dual partition:  (4, 2, 0)
# The dBV(dO): M, [3, 3]
# #DRCS:  12,     #ALS    12
# #GDRCS: 12,     #GLS    12
# Group type B, dual partition:  (4, 4, 2, 0)
# The dBV(dO): B, [5, 3, 3]
# #PBPext:        48, #PBPext*2:  96,     #ALS    96
# #GPBPext:       48, #GPBPext*2: 96,     #GLS    96
# Group type M, dual partition:  (4, 4, 4, 2, 0)
# The dBV(dO): M, [4, 4, 3, 3]
# #DRCS:  36,     #ALS    36
# #GDRCS: 36,     #GLS    36
# Group type B, dual partition:  (4, 4, 4, 4, 2, 0)
# The dBV(dO): B, [5, 4, 4, 3, 3]
# #PBPext:        96, #PBPext*2:  192,    #ALS    192
# #GPBPext:       96, #GPBPext*2: 192,    #GLS    192

# %%
part, rtype = (2,2,2,2,2,2,1,1), 'M'
#part, rtype = (2,2,2,2,2,2,2,2,2,2), 'M'
part, rtype = (2,2), 'C'
part, rtype = (5,5,2,2), 'M'
part2drc(part,rtype=rtype,print_Wrepn=True,printdig=False)
gg = gen_lift_graph(part,rtype,format='pdf')
gg.render()
display(gg)
# Out:
# Type M partition: (5, 5, 2, 2)
# List of relevent Weyl group representations
# [([3, 1], [2, 1]), ([2, 1], [3, 1])]
# [34, 34]
# Number of drc diagrams: 68
# [3]
# Partition type B  (3,):
# #DRCS:  3,      #ALS    12
# #GDRCS: 6,      #GLS    12
# [5]
# Partition type M  (2, 2):
# #DRCS:  5,      #ALS    5
# #GDRCS: 5,      #GLS    5
# [17]
# Partition type B  (5, 2, 2):
# #DRCS:  17,     #ALS    68
# #GDRCS: 34,     #GLS    68
# [34, 34]
# Partition type M  (5, 5, 2, 2):
# #DRCS:  68,     #ALS    68
# #GDRCS: 68,     #GLS    68

# %%
part, rtype = (3,3,1,1), 'M'
part2drc(part,rtype=rtype,print_Wrepn=True,printdig=True);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 part, rtype = (3,3,1,1), 'M'
# ----> 2 part2drc(part,rtype=rtype,print_Wrepn=True,printdig=True);
#
# NameError: name 'part2drc' is not defined

# %%
part = [7,7,6,6,5,5,4,4,3,3,2,2,1,1]
part = [7,7,5,5,3,3,1,1]
part = [13,13,2,2,1,1]
#part = [3,3,2,2,1,1]
#part = [2,2,1,1]
part = [8,8,8,8,8,8,5,5,2,2,2,2,2,2,2,2]
part = [4,4,4,4,4,4,2,2,2,2,2,2,2,2]
rtype = 'M'

test_purelyeven(part,rtype=rtype);

# %%
part = [7,5,5,3,3]
#part = [5,4,4]
part = [15,13,13,8,8,8,8,3,3,2,2,2,2,1,1]

b = part2drc(part,'B',print_Wrepn=False,printdig=False)
c = print_list_LS(part,'B')
#compare_drc(a,b)

# %%
part = (8,8,7,7,5,5,1,1)
rtype = 'M'
test_purelyeven(part,rtype=rtype);

# %%
part = [2,2,2,2,2,2,2,2,1,1]
rtype = 'M'
test_purelyeven(part,rtype=rtype);

# %%
## Example of strange annihlation of LS
test_LSDRC([8,3,3,1,1],'D',report=False,reportann=True)

# %%
test_LSDRC([4,3,3,2,2,1,1],'D',report=False, reportann=True)

# %%
partM = [3,3]
DRCLS1 = lift_drcs(dict(),rtype='B',ltype=partM[-1])
DRCLS2 = lift_drcs(DRCLS1, rtype='M', ltype='l')
print_list_LS(partM,'M')
print_DRCLS(DRCLS1, 'B')
print('DRCLS',len(DRCLS2))
print_DRCLS(DRCLS2,'M')

# %%
test_LSDRC([9,6,6,3,3,2,2,1,1],'B',report=False)

# %%
test_LSDRC([7,6,6,5,5,4,4,3,3,2,2,1,1],'B',report=False)

# %%
test_LSDRC([6,5,5,4,4,3,3,2,2,1,1],'D',report=False)

# %%
test_LSDRC([6,6,5,5,4,4,3,3,2,2,1,1],'M', report=False)

# %%
#part0, parta, rtype=(3,3,2,2,1,1), (3,3), 'C'
part0, parta, rtype=(1,1), (1,1), 'C'
part = parta*2+part0
part2drc(part0,rtype, printdig=True)
part2LS(part0,rtype, printdig=True)
#part, rtype=[1,1,1,1], 'C'
part2drc(part,rtype,printdig = True)
part2LS(part,rtype, printdig=True)

# %%
#part,rtype=(4,3,3,1,1), 'D'
part,rtype=(1,1,)*5,'C'
test_LSDRC(part,rtype,report=True,reportann=False)

# %%
#part,rtype=(4,3,3,1,1), 'D'
part,rtype=(5,5)*4+(3,3,)*5+(2,2),'C'
#part,rtype=(6,6,2,2,1,1),'C'
#part,rtype=(1,1,)*5,'C'
part,rtype=(7,7)*5+(2,2)+(1,1)*4,'C'
test_purelyeven(part,rtype,report=False,reportann=False)

# %%
#part,rtype=(4,3,3,1,1), 'D'
#part,rtype=(5,5)*4+(4,4)+(3,3,)*4+(2,2)+(1,1,)*4,'C'
part,rtype=(4,4)*5+(3,3)+(2,2,)*5,'M'
#part,rtype=(2,2,)*4,'M'
test_purelyeven(part,rtype,report=False,reportann=False)
0

# %%
#part,rtype=(4,3,3,1,1), 'D' 
#part,rtype=(5,5)*4+(4,4)+(3,3,)*4+(2,2)+(1,1,)*4,'C'
part,rtype=(3,3,)*5+(2,2),'C'
test_purelyeven(part,rtype,report=False,reportann=False,reportpack=False)

# %%
#part,rtype=(4,3,3,1,1), 'D'
#part,rtype=(5,5)*4+(4,4)+(3,3,)*4+(2,2)+(1,1,)*4,'C'
#part,rtype=(4,4)*5+(3,3)+(2,2,)*5,'M'
part,rtype=(4,2,2,),'D'
test_purelyeven(part,rtype,report=True,reportann=False)

# %%
part,rtype=(2,1,1,),'D'
test_purelyeven(part,rtype,report=False,reportann=False);

# %%
part,rtype=(3,1,1,),'D'
test_purelyeven(part,rtype,report=True,reportann=False)
0

# %%
''.join(range(0))

# %%
a = 'abc'
('',*a)

# %%
springer_part2repn((3,3,3),'C')

# %%
springer_repn2part(((3,2),(2,1)),'D')

# %%
dO,rtype = (5,5,1),'C'
RR = dualpart2Wrepn(dO,rtype)
print(RR)

# %%
dO, rtype = (6,6,6,6,4,4,4,4),'D'
stau = part2srepn(dO,rtype)
print(stau)
RES = part2dbcell(dO,rtype)
print(RES)

# %%
dO, rtype = (7,7,4,4,4,4,1,1),'C'
print(dualBVW(dO,'C',partrc='c'))

# %%
dO, rtype = (1,1),'D'
stau = part2srepn(dO,rtype)
print(stau)

# %%
part, rtype = (10,8,6,4,2), 'C'
#part, rtype = (2,2,2,2,2,2,2,2,2,2), 'M'

part2drc(part,rtype=rtype,print_Wrepn=True,printdig=False)
gg = gen_lift_graph(part,rtype,format='pdf')
gg.render()
display(gg)

# %%
part, rtype = (6,6,5,5,2,2), 'C'
#part, rtype = (2,2,2,2,2,2,2,2,2,2), 'M'

part2drc(part,rtype=rtype,print_Wrepn=True,printdig=False)
gg = gen_lift_graph(part,rtype,format='pdf')
gg.render()
display(gg)

# %%
part, rtype = (2,2,2,2,2,2,1,1), 'M'
#part, rtype = (2,2,2,2,2,2,2,2,2,2), 'M'
part, rtype = (1,1,1,1), 'C'
part, rtype = (5,5,3,3,1,1), 'C'
#part, rtype = (1,1,1,1,1,1), 'C'
part, rtype = (2,2,2,2,1,1), 'M'
#part2drc(part,rtype=rtype,print_Wrepn=False,printdig=False)
gg = gen_lift_graph(part,rtype,format='pdf')
gg.render()
display(gg)
# Out:
# [1]
# Partition type B  (1,):
# #DRCS:  1,      #ALS    4
# #GDRCS: 2,      #GLS    4
# [2, 2]
# Partition type M  (1, 1):
# #DRCS:  4,      #ALS    4
# #GDRCS: 4,      #GLS    4
# [4, 4]
# Partition type B  (3, 1, 1):
# #DRCS:  8,      #ALS    32
# #GDRCS: 16,     #GLS    32
# [6, 6]
# Partition type M  (2, 2, 1, 1):
# #DRCS:  12,     #ALS    12
# #GDRCS: 12,     #GLS    12
# [8, 8]
# Partition type B  (3, 2, 2, 1, 1):
# #DRCS:  16,     #ALS    64
# #GDRCS: 32,     #GLS    64
# [10, 10]
# Partition type M  (2, 2, 2, 2, 1, 1):
# #DRCS:  20,     #ALS    20
# #GDRCS: 20,     #GLS    20

# %%
a = 'b'
a[-1:]
